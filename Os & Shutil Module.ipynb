# %%
pwd
# Out:
# '/Users/CalebIuliano/hackreactor/python-practice'

# %%
f = open('practice.txt', 'w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/CalebIuliano/hackreactor/python-practice'

# %%
os.listdir()
# Out:
# ['advancedPythonModules',
#  'elif statements.ipynb',
#  'Decorators.ipynb',
#  'Numbers.ipynb',
#  'Sets.ipynb',
#  'Untitled.ipynb',
#  'textfiles.ipynb',
#  'Generators.ipynb',
#  '*args **kwargs.ipynb',
#  'List comprehensions.ipynb',
#  'Forloop.ipynb',
#  'practice.txt',
#  'Lists.ipynb',
#  'mainPackage',
#  'Tuples.ipynb',
#  'Tuple unpacking.ipynb',
#  'Collections Module.ipynb',
#  'myProgram.py',
#  'Functions.ipynb',
#  'Os & Shutil Module.ipynb',
#  'Lamnda functions.ipynb',
#  'Object Oriented Programming.ipynb',
#  'mainScript.py',
#  'variables.ipynb',
#  'War.ipynb',
#  'Dictionaries.ipynb',
#  'createModules',
#  'test.txt',
#  'myfile.txt',
#  '.ipynb_checkpoints',
#  'while loops.ipynb',
#  'Strings.ipynb',
#  '.git',
#  'error handling.ipynb',
#  'testfile',
#  'useful operators.ipynb']

# %%
import shutil

# %%
shutil.move('practice.txt', '/Users/CalebIuliano/hackreactor/python-practice/test')
# Out:
# '/Users/CalebIuliano/hackreactor/python-practice/test'

# %%
os.listdir()
# Out:
# ['advancedPythonModules',
#  'elif statements.ipynb',
#  'Decorators.ipynb',
#  'Numbers.ipynb',
#  'test',
#  'Sets.ipynb',
#  'Untitled.ipynb',
#  'textfiles.ipynb',
#  'Generators.ipynb',
#  '*args **kwargs.ipynb',
#  'List comprehensions.ipynb',
#  'Forloop.ipynb',
#  'Lists.ipynb',
#  'mainPackage',
#  'Tuples.ipynb',
#  'Tuple unpacking.ipynb',
#  'Collections Module.ipynb',
#  'myProgram.py',
#  'Functions.ipynb',
#  'Os & Shutil Module.ipynb',
#  'Lamnda functions.ipynb',
#  'Object Oriented Programming.ipynb',
#  'mainScript.py',
#  'variables.ipynb',
#  'War.ipynb',
#  'Dictionaries.ipynb',
#  'createModules',
#  'test.txt',
#  'myfile.txt',
#  '.ipynb_checkpoints',
#  'while loops.ipynb',
#  'Strings.ipynb',
#  '.git',
#  'error handling.ipynb',
#  'testfile',
#  'useful operators.ipynb']

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['advancedPythonModules',
#  'elif statements.ipynb',
#  'Decorators.ipynb',
#  'Numbers.ipynb',
#  'test',
#  'Sets.ipynb',
#  'Untitled.ipynb',
#  'textfiles.ipynb',
#  'Generators.ipynb',
#  '*args **kwargs.ipynb',
#  'List comprehensions.ipynb',
#  'Forloop.ipynb',
#  'Lists.ipynb',
#  'mainPackage',
#  'Tuples.ipynb',
#  'Tuple unpacking.ipynb',
#  'Collections Module.ipynb',
#  'myProgram.py',
#  'Functions.ipynb',
#  'Os & Shutil Module.ipynb',
#  'Lamnda functions.ipynb',
#  'Object Oriented Programming.ipynb',
#  'mainScript.py',
#  'variables.ipynb',
#  'War.ipynb',
#  'Dictionaries.ipynb',
#  'createModules',
#  'test.txt',
#  'myfile.txt',
#  '.ipynb_checkpoints',
#  'while loops.ipynb',
#  'Strings.ipynb',
#  '.git',
#  'error handling.ipynb',
#  'testfile',
#  'useful operators.ipynb']

# %%
os.getcwd()
# Out:
# '/Users/CalebIuliano/hackreactor/python-practice'

# %%
filepath = '/Users/CalebIuliano/hackreactor/python-practice'

# %%
for folder, sub_folders, files in os.walk(filepath):
    print(f"Currently looking at {folder}")
    print('\n')
    print("The subfolders are: ")
    for sub_fold in sub_folders:
        print(f"Subfolder: {sub_fold}")
    print('\n')
    print("the files are: ")
    for f in files:
        print(f"file: {f}")
    print("\n")
# Out:
# Currently looking at /Users/CalebIuliano/hackreactor/python-practice
#
#
# The subfolders are:
# Subfolder: advancedPythonModules
# Subfolder: mainPackage
# Subfolder: createModules
# Subfolder: .ipynb_checkpoints
# Subfolder: .git
#
#
# the files are:
# file: elif statements.ipynb
# file: Decorators.ipynb
# file: Numbers.ipynb
# file: test
# file: Sets.ipynb
# file: Untitled.ipynb
# file: textfiles.ipynb
# file: Generators.ipynb
# file: *args **kwargs.ipynb
# file: List comprehensions.ipynb
# file: Forloop.ipynb
# file: Lists.ipynb
# file: Tuples.ipynb
# file: Tuple unpacking.ipynb
# file: Collections Module.ipynb
# file: myProgram.py
# file: Functions.ipynb
# file: Os & Shutil Module.ipynb
# file: Lamnda functions.ipynb
# file: Object Oriented Programming.ipynb
# file: mainScript.py
# file: variables.ipynb
# file: War.ipynb
# file: Dictionaries.ipynb
# file: test.txt
# file: myfile.txt
# file: while loops.ipynb
# file: Strings.ipynb
# file: error handling.ipynb
# file: testfile
# ...
